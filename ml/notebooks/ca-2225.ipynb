# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/raw/ca-2225.csv")
df.head()
# Out:
#   Reporting Area  Current MMWR Year  MMWR WEEK  \
# 0     CALIFORNIA               2022          1
# 1     CALIFORNIA               2022          1
# 2     CALIFORNIA               2022          1
# 3     CALIFORNIA               2022          1
# 4     CALIFORNIA               2022          1
#
#                                                Label  Current week  \
# 0                                 Campylobacteriosis          47.0
# 1                                 Coccidioidomycosis          10.0
# 2                                  Measles, Imported           NaN
# 3                                Measles, Indigenous           NaN
# 4  Salmonellosis (excluding Salmonella Typhi infe...           1.0
#
#   Current week, flag  Previous 52 week Max Previous 52 weeks Max, flag  \
# 0                  -                   249                           -
# 1                  -                   212                           -
# ...

# %%
df.shape
# Out:
# (1106, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1106 entries, 0 to 1105
# Data columns (total 16 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Reporting Area                           1106 non-null   object
#  1   Current MMWR Year                        1106 non-null   int64
#  2   MMWR WEEK                                1106 non-null   int64
#  3   Label                                    1106 non-null   object
#  4   Current week                             703 non-null    float64
#  5   Current week, flag                       950 non-null    object
#  6   Previous 52 week Max                     1106 non-null   int64
#  7   Previous 52 weeks Max, flag              878 non-null    object
#  8   Cumulative YTD Current MMWR Year         935 non-null    object
#  9   Cumulative YTD Current MMWR Year, flag   892 non-null    object
# ...

# %%
df = df.drop("Current week, flag", axis=1)
df = df.drop("Previous 52 weeks Max, flag", axis=1)
df = df.drop("Cumulative YTD Current MMWR Year, flag", axis=1)
df = df.drop("Cumulative YTD Previous MMWR Year, flag", axis=1)
df = df.drop("LOCATION2", axis=1)
df.head()
# Out:
#   Reporting Area  Current MMWR Year  MMWR WEEK  \
# 0     CALIFORNIA               2022          1
# 1     CALIFORNIA               2022          1
# 2     CALIFORNIA               2022          1
# 3     CALIFORNIA               2022          1
# 4     CALIFORNIA               2022          1
#
#                                                Label  Current week  \
# 0                                 Campylobacteriosis          47.0
# 1                                 Coccidioidomycosis          10.0
# 2                                  Measles, Imported           NaN
# 3                                Measles, Indigenous           NaN
# 4  Salmonellosis (excluding Salmonella Typhi infe...           1.0
#
#    Previous 52 week Max Cumulative YTD Current MMWR Year  \
# 0                   249                               47
# 1                   212                               10
# 2                     0                              NaN
# ...

# %%
df = df[~df['Label'].str.contains('measles, imported|measles, indigenous', case=False, na=False)]
df.head()
# Out:
#   Reporting Area  Current MMWR Year  MMWR WEEK  \
# 0     CALIFORNIA               2022          1
# 1     CALIFORNIA               2022          1
# 4     CALIFORNIA               2022          1
# 5     CALIFORNIA               2022          2
# 6     CALIFORNIA               2022          2
#
#                                                Label  Current week  \
# 0                                 Campylobacteriosis          47.0
# 1                                 Coccidioidomycosis          10.0
# 4  Salmonellosis (excluding Salmonella Typhi infe...           1.0
# 5                                 Campylobacteriosis          30.0
# 6                                 Coccidioidomycosis           8.0
#
#    Previous 52 week Max Cumulative YTD Current MMWR Year  \
# 0                   249                               47
# 1                   212                               10
# 4                   102                                1
# ...

# %%
df = df.reset_index(drop=True)
df.head()
# Out:
#   Reporting Area  Current MMWR Year  MMWR WEEK  \
# 0     CALIFORNIA               2022          1
# 1     CALIFORNIA               2022          1
# 2     CALIFORNIA               2022          1
# 3     CALIFORNIA               2022          2
# 4     CALIFORNIA               2022          2
#
#                                                Label  Current week  \
# 0                                 Campylobacteriosis          47.0
# 1                                 Coccidioidomycosis          10.0
# 2  Salmonellosis (excluding Salmonella Typhi infe...           1.0
# 3                                 Campylobacteriosis          30.0
# 4                                 Coccidioidomycosis           8.0
#
#    Previous 52 week Max Cumulative YTD Current MMWR Year  \
# 0                   249                               47
# 1                   212                               10
# 2                   102                                1
# ...

# %%
df = df.drop("sort_order", axis=1)
df = df.drop("geocode", axis=1)
df = df.drop("LOCATION1", axis=1)
df.head()
# Out:
#   Reporting Area  Current MMWR Year  MMWR WEEK  \
# 0     CALIFORNIA               2022          1
# 1     CALIFORNIA               2022          1
# 2     CALIFORNIA               2022          1
# 3     CALIFORNIA               2022          2
# 4     CALIFORNIA               2022          2
#
#                                                Label  Current week  \
# 0                                 Campylobacteriosis          47.0
# 1                                 Coccidioidomycosis          10.0
# 2  Salmonellosis (excluding Salmonella Typhi infe...           1.0
# 3                                 Campylobacteriosis          30.0
# 4                                 Coccidioidomycosis           8.0
#
#    Previous 52 week Max Cumulative YTD Current MMWR Year  \
# 0                   249                               47
# 1                   212                               10
# 2                   102                                1
# ...

# %%
df = df.drop(["Previous 52 week Max", "Cumulative YTD Current MMWR Year", "Cumulative YTD Previous MMWR Year"], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df = df.drop(["Previous 52 week Max", "Cumulative YTD Current MMWR Year", "Cumulative YTD Previous MMWR Year"], axis = 1)
#
# File c:\Users\ryanh\code\projects\RegionalOutbreakPredictor\ml\venv\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
# ...

# %%
df.head()
# Out:
#   Reporting Area  Current MMWR Year  MMWR WEEK  \
# 0     CALIFORNIA               2022          1
# 1     CALIFORNIA               2022          1
# 2     CALIFORNIA               2022          1
# 3     CALIFORNIA               2022          2
# 4     CALIFORNIA               2022          2
#
#                                                Label  Current week
# 0                                 Campylobacteriosis          47.0
# 1                                 Coccidioidomycosis          10.0
# 2  Salmonellosis (excluding Salmonella Typhi infe...           1.0
# 3                                 Campylobacteriosis          30.0
# 4                                 Coccidioidomycosis           8.0

# %%
df = df.rename(columns={
    "Reporting Area": "REGION",
    "Current MMWR Year": "YEAR",
    "MMWR WEEK": "WEEK",
    "Label": "LABEL",
    "Current week": "TOTAL CASES",
})

# %%
df.head()
# Out:
#        REGION  YEAR  WEEK                                              LABEL  \
# 0  CALIFORNIA  2022     1                                 Campylobacteriosis
# 1  CALIFORNIA  2022     1                                 Coccidioidomycosis
# 2  CALIFORNIA  2022     1  Salmonellosis (excluding Salmonella Typhi infe...
# 3  CALIFORNIA  2022     2                                 Campylobacteriosis
# 4  CALIFORNIA  2022     2                                 Coccidioidomycosis
#
#    TOTAL CASES
# 0         47.0
# 1         10.0
# 2          1.0
# 3         30.0
# 4          8.0

# %%
df.to_csv('df-2225.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 720 entries, 0 to 719
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   REGION       720 non-null    object
#  1   YEAR         720 non-null    int64
#  2   WEEK         720 non-null    int64
#  3   LABEL        720 non-null    object
#  4   TOTAL CASES  690 non-null    float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 28.3+ KB
